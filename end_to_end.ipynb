# %%
import csv
import matplotlib.pyplot as plt
import math
from matplotlib.ticker import FuncFormatter
import numpy as np

# %%
greedy_weights = []
shortest_weights = []
with open('../_output.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        if row[0] == 'greedy':
            greedy_weights.append(math.log10(float(row[2])))
        elif row[0] == 'shortest':
            shortest_weights.append(math.log10(float(row[2])))

x = range(1, len(greedy_weights) + 1)
y1 = greedy_weights
y2 = shortest_weights

plt.plot(x, y1, label="Heuristic algorithm")
plt.plot(x, y2, label="Dijkstra-based algorithm")

old_yticks = [-1,-2,-3,-4]
old_xticks = [int(x) for x in np.linspace(0, 150, 5)]

def format_y_ticks(value, pos):
    return fr"$10^{{{value}}}$"

def format_x_ticks(value, pos):
    return fr"${value}^{{th}}$"

plt.gca().yaxis.set_major_formatter(FuncFormatter(format_y_ticks))
plt.gca().set_yticks(old_yticks)
plt.gca().xaxis.set_major_formatter(FuncFormatter(format_x_ticks))
plt.gca().set_xticks(old_xticks)

plt.xlabel('Execution')
plt.ylabel('Runtime (seconds)')
plt.xlim(left=0, right=150)
plt.legend()
plt.show()
# greedy_weights = []
# shortest_weights = []
# with open('../_output.csv', 'r') as csvfile:
#     reader = csv.reader(csvfile)
#     for row in reader:
#         if row[0] == 'greedy':
#             greedy_weights.append(row[2])
#         elif row[0] == 'shortest':
#             shortest_weights.append(row[2])

# x = range(1, len(greedy_weights) + 1)
# y1 = greedy_weights
# y2 = shortest_weights
# y_1 = np.array(y2).astype(float) / np.array(y1).astype(float)

# %%
greedy_times = []
shortest_times = []
with open('../_output.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        if row[0] == 'greedy':
            greedy_times.append(float(row[1]))
        elif row[0] == 'shortest':
            shortest_times.append(float(row[1]))
x = range(1, len(greedy_times) + 1)
y1 = greedy_times
y2 = shortest_times

plt.plot(x, y1, label="Heuristic algorithm")
plt.plot(x, y2, label="Dijkstra-based algorithm")
plt.gca().xaxis.set_major_formatter(FuncFormatter(format_x_ticks))
plt.gca().set_xticks(old_xticks)

plt.xlabel('Execution')
plt.ylabel('Delay (seconds)')
plt.xlim(left=0,right=150)
plt.legend()
plt.show()
# greedy_times = []
# shortest_times = []
# with open('../output.csv', 'r') as csvfile:
#     reader = csv.reader(csvfile)
#     for row in reader:
#         if row[0] == 'greedy':
#             greedy_times.append(float(row[1]))
#         elif row[0] == 'shortest':
#             shortest_times.append(float(row[1]))
# x = range(1, len(greedy_times) + 1)
# y1 = greedy_times
# y2 = shortest_times

# y_2 = np.array(y2).astype(float) / np.array(y1).astype(float)
# y = [a_i - b_i for a_i, b_i in zip(y1,y2)]

# %%
# Customization options
c1 = "lightyellow"
mean_color = "green"

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(6, 8))
axs[0].tick_params(axis='both', which='major', labelsize=14)
axs[1].tick_params(axis='both', which='major', labelsize=14)


# Box plot for the first dataset (subplot 1)
axs[0].boxplot(y_1,
               patch_artist=True,
               boxprops=dict(facecolor=c1),
               medianprops=dict(color=mean_color, linewidth=5))
axs[0].set_xticks([1])
axs[0].set_xticklabels(['Runtime ratio'])
axs[0].set_yticks([10,20,30,40,50,100,200])

# Box plot for the second dataset (subplot 2)
axs[1].boxplot(y_2,
               patch_artist=True,
               boxprops=dict(facecolor=c1),
               medianprops=dict(color=mean_color, linewidth=5))
axs[1].set_xticks([1])
axs[1].set_xticklabels(['Transmission delay ratio'])

fig.suptitle(
    ' Heuristic Algorithm and the Dijkstra-based Algorithm\n Results Analysis',
    fontsize=16)

fig.tight_layout(pad=2)

plt.show()

# %%
# Out:
# array([[ 13.24480937,   0.79704019],
#        [  9.20827137,   0.64620625],
#        [ 12.47145372,   0.73252739],
#        [ 43.828184  ,   0.47859387],
#        [133.8739804 ,   0.79525467],
#        [ 30.25445448,   0.56227724],
#        [ 23.56693472,   0.63628479],
#        [ 18.96152383,   0.51583544],
#        [ 20.10381037,   0.50918101],
#        [ 21.78044657,   0.48493748],
#        [ 25.87407939,   0.48872203],
#        [ 26.866686  ,   0.62564975],
#        [ 91.84637644,   0.87856642],
#        [ 24.85197943,   0.49831104],
#        [ 29.46487193,   0.6641521 ],
#        [ 44.96787418,   0.72446028],
#        [ 16.93205146,   0.49544623],
#        [ 91.2801785 ,   0.78340771],
#        [ 12.71737337,   0.48468573],
#        [ 71.19687659,   0.65245014],
#        [ 47.31365997,   0.60606554],
#        [ 11.18030168,   0.58032938],
#        [ 77.97880058,   0.69962334],
#        [ 16.31979599,   0.52172965],
#        [ 74.19171187,   0.68626638],
#        [ 22.1174126 ,   0.58444932],
#        [ 10.98108942,   0.71823981],
#        [ 25.87103391,   0.75131578],
#        [ 30.1679789 ,   0.48903473],
#        [ 19.61848039,   0.50569354],
#        [ 13.0971799 ,   0.58340528],
#        [ 18.51599939,   0.69359204],
#        [ 60.2111615 ,   0.63725271],
#        [ 18.34770151,   0.40933675],
#        [ 53.73227957,   0.53066499],
#        [ 34.62532354,   0.53283687],
#        [ 26.51087134,   0.56320954],
#        [ 34.36592019,   0.71736723],
#        [ 82.13402843,   0.45706474],
#        [ 29.67841768,   0.59844108],
#        [ 25.22039326,   0.7109311 ],
#        [ 28.2000123 ,   0.63787611],
#        [ 18.20175354,   0.59548083],
#        [ 28.56924704,   0.51905739],
#        [ 27.96817007,   0.48784487],
#        [ 12.80854882,   0.5476379 ],
#        [ 44.39071136,   0.59972161],
#        [ 31.34970884,   0.71448604],
#        [ 40.16364117,   0.7082015 ],
#        [ 20.64776964,   0.67420184],
#        [ 76.75610086,   0.60408722],
#        [ 12.23240507,   0.64648726],
#        [ 21.52819692,   0.54434898],
#        [ 31.59821355,   0.51380398],
#        [ 93.86478932,   0.57790435],
#        [ 17.33006181,   0.63698743],
#        [ 29.97145556,   0.50754764],
#        [ 11.91906495,   0.49516244],
#        [ 10.20781854,   0.49677005],
#        [ 72.07869996,   0.79665068],
#        [125.15751954,   0.79298572],
#        [ 24.1484149 ,   0.60331554],
#        [ 10.36565359,   0.47851126],
#        [ 78.67828373,   0.66946834],
#        [ 38.76857127,   0.60435884],
#        [ 29.39398545,   0.4961647 ],
#        [ 74.24752221,   0.77280158],
#        [ 26.96478508,   0.54367648],
#        [ 23.73205593,   0.5758062 ],
#        [ 38.03320193,   0.66484818],
#        [ 14.75534896,   0.61304351],
#        [ 29.8692637 ,   0.63264247],
#        [ 26.03503233,   0.66552119],
#        [ 15.42471182,   0.47032326],
#        [ 50.37341104,   0.60765133],
#        [  8.74366893,   0.58916015],
#        [ 20.05713057,   0.50460962],
#        [ 36.31966655,   0.67710063],
#        [ 96.47743519,   0.81974682],
#        [ 30.62789493,   0.60473808],
#        [ 13.12507848,   0.54380566],
#        [ 27.24598366,   0.59839245],
#        [ 34.87973417,   0.49163911],
#        [ 28.50997174,   0.64585441],
#        [ 72.44855035,   0.57397503],
#        [ 62.21249223,   0.54200776],
#        [ 43.6426983 ,   0.64339231],
#        [ 17.69334067,   0.55064373],
#        [ 16.51013047,   0.42987545],
#        [ 35.74323659,   0.6008475 ],
#        [ 11.38727811,   0.64423055],
#        [ 34.37387068,   0.71830382],
#        [ 14.74424954,   0.66034653],
#        [ 31.56342489,   0.46074703],
#        [ 19.66588109,   0.40246183],
#        [ 25.13392772,   0.49138072],
#        [ 32.19019923,   0.69136679],
#        [ 30.02845452,   0.6410957 ],
#        [ 22.25205421,   0.50638507],
#        [ 88.00666746,   0.72478319],
#        [ 15.54716633,   0.64945263],
#        [ 27.14102568,   0.56425306],
#        [  8.44193677,   0.59079212],
#        [ 32.04246649,   0.63322817],
#        [ 61.98986533,   0.70131776],
#        [ 39.25226413,   0.6529507 ],
#        [ 41.72829602,   0.63872615],
#        [ 22.75988231,   0.57727546],
#        [ 72.31548811,   0.89982542],
#        [ 42.78629088,   0.64959635],
#        [ 20.3540909 ,   0.49735719],
#        [ 46.51774891,   0.4934161 ],
#        [ 30.4462563 ,   0.56904729],
#        [ 20.92517508,   0.50270785],
#        [ 45.30151749,   0.47895233],
#        [ 52.69812692,   0.64126382],
#        [ 20.72678615,   0.54613479],
#        [ 31.96279546,   0.59028309],
#        [ 28.22428334,   0.66898815],
#        [ 65.46611519,   0.64913243],
#        [ 25.25883271,   0.65687405],
#        [ 40.99209709,   0.57111193],
#        [ 94.30574293,   0.73314789],
#        [ 35.8467613 ,   0.66241036],
#        [ 44.77431061,   0.6763848 ],
#        [ 20.03385695,   0.65679448],
#        [ 19.15922311,   0.50985884],
#        [ 25.61662156,   0.60463624],
#        [ 31.49399248,   0.67655707],
#        [ 46.76601193,   0.55331384],
#        [ 93.94574417,   0.77541634],
#        [ 19.54234476,   0.57649038],
#        [ 32.78125851,   0.82414274],
#        [ 36.56552926,   0.58141962],
#        [ 41.21910606,   0.69501803],
#        [ 51.51804239,   0.63393404],
#        [ 39.48949025,   0.64004277],
#        [ 52.59544545,   0.70459649],
#        [ 25.48824648,   0.71947853],
#        [ 25.78815633,   0.68043898],
#        [ 56.48513763,   0.76986616],
#        [ 33.29200008,   0.50394081],
#        [ 95.77948543,   0.68023864],
#        [ 46.98686783,   0.64691396],
#        [ 18.84941746,   0.37312606],
#        [ 18.0290652 ,   0.48883142],
#        [ 16.3546943 ,   0.58585143],
#        [ 39.58767684,   0.65287012],
#        [ 61.92137897,   0.54895903]])
